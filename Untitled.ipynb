# %%
pip install streamlit python-dotenv google-generativeai Pillow audio-recorder-streamlit SpeechRecognition pydub
# Out:
# Requirement already satisfied: streamlit in e:\program file\lib\site-packages (1.50.0)
# Requirement already satisfied: python-dotenv in e:\program file\lib\site-packages (1.1.1)
# Requirement already satisfied: google-generativeai in e:\program file\lib\site-packages (0.8.5)
# Requirement already satisfied: Pillow in e:\program file\lib\site-packages (11.3.0)
# Requirement already satisfied: audio-recorder-streamlit in e:\program file\lib\site-packages (0.0.10)
# Requirement already satisfied: SpeechRecognition in e:\program file\lib\site-packages (3.14.3)
# Requirement already satisfied: pydub in e:\program file\lib\site-packages (0.25.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in e:\program file\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in e:\program file\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in e:\program file\lib\site-packages (from streamlit) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in e:\program file\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in e:\program file\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: packaging<26,>=20 in e:\program file\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in e:\program file\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: protobuf<7,>=3.20 in e:\program file\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in e:\program file\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in e:\program file\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in e:\program file\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in e:\program file\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in e:\program file\lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in e:\program file\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in e:\program file\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in e:\program file\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in e:\program file\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: entrypoints in e:\program file\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in e:\program file\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in e:\program file\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: toolz in e:\program file\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (1.0.0)
# Requirement already satisfied: colorama in e:\program file\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in e:\program file\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in e:\program file\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\program file\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\program file\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\program file\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\program file\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in e:\program file\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\program file\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\program file\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in e:\program file\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in e:\program file\lib\site-packages (from google-generativeai) (2.26.0)
# Requirement already satisfied: google-api-python-client in e:\program file\lib\site-packages (from google-generativeai) (2.184.0)
# Requirement already satisfied: google-auth>=2.15.0 in e:\program file\lib\site-packages (from google-generativeai) (2.41.1)
# Requirement already satisfied: pydantic in e:\program file\lib\site-packages (from google-generativeai) (2.12.0)
# Requirement already satisfied: tqdm in e:\program file\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in e:\program file\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in e:\program file\lib\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in e:\program file\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in e:\program file\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\program file\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\program file\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in e:\program file\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: standard-aifc in e:\program file\lib\site-packages (from SpeechRecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in e:\program file\lib\site-packages (from SpeechRecognition) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\program file\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in e:\program file\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\program file\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\program file\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\program file\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.0)
# Requirement already satisfied: six>=1.5 in e:\program file\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in e:\program file\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in e:\program file\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in e:\program file\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in e:\program file\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\program file\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in e:\program file\lib\site-packages (from pydantic->google-generativeai) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\program file\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: standard-chunk in e:\program file\lib\site-packages (from standard-aifc->SpeechRecognition) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile app1.py
from dotenv import load_dotenv
load_dotenv()

import streamlit as st
import os
import google.generativeai as genai
from datetime import datetime


genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))


if "chat_history" not in st.session_state:
    st.session_state.chat_history=[]
if "dia_entries" not in st.session_state:
    st.session_state.dia_entries = []
if 'User_profile' not in st.session_state:
    st.session_state.User_profile = {
        'Nickname' : '',
        'Age' : '' ,
        'Occupation' : '',
        'Medical conditions' : 'None'
    }
def get_gemini_response(input_prompt):
    model = genai.GenerativeModel('gemini-2.5-flash')
    content = [input_prompt]
    try:
        response = model.generate_content(content)
        return response.text
    except Exception as e:
        return f"Error generating response: {str(e)}"
        
st.set_page_config(page_title="AI Mental Health Companion", layout="wide")
st.header("AI Mental Health Companion")

with st.sidebar:
    st.subheader("User Profile")
    
    nickname = st.text_area("Nickname",
                            value=st.session_state.User_profile['Nickname'],
                            placeholder="Set any name that bot call to you.(Optional)")
    age_options = ["select", "4-10 years", "11-18 years", "19-25 years", "26-45 years", "45-80 years"]
    age_index = age_options.index(st.session_state.User_profile['Age']) if st.session_state.User_profile['Age'] in age_options else 0
    age = st.selectbox("Age", age_options, index=age_index)
    
    occupation = st.text_area("Occupation",
                             value=st.session_state.User_profile['Occupation'],
                             placeholder="Student\Professionals")
    medical_conditions = st.text_area("Medical conditions",
                                      value=st.session_state.User_profile['Medical conditions'])
    
    if st.button("Update Profile"):
        st.session_state.User_profile = {
            'Nickname': nickname,
            'Age' : age,
            'Occupation' : occupation,
            'Medical conditions' : medical_conditions
        }
        st.success("Profile updated!")

tab1, tab2 = st.tabs(["Professional counselors", "Diary"])

with tab1:
    st.subheader("🌞Personalized Professional counselors")
    col1, col2 = st.columns(2)
    with col1:
        st.write("### Chitchat with AI")
        mood = st.radio("How are you feeling today?", ["😣anxious", "😨stressed", "😁Happy"])
        user_input = st.text_area("What's on your mind free-to expressions:",
                                  placeholder="e.g., 'I feel anxious about exam'")
    with col2:
        st.write("### Your Profile")
        st.json(st.session_state.User_profile)

    if st.button("Send 🚀"):
        is_profile_complete = (
            st.session_state.User_profile['Nickname'] != '',
            st.session_state.User_profile['Age'] != 'select' and
            st.session_state.User_profile['Occupation'] != ''
        )

        if not is_profile_complete:
            st.warning("Please complete your profile in the sidebar first")
        else:
            with st.spinner("Creating your Personalized counselors..."):
                prompt = f"""
                Dear {st.session_state.User_profile['Nickname']},
                Respond to the user in an empathetic and mood-matching tone. For example, if the user is happy, say, "I'm so happy to hear that!" or if the user is feeling anxious,
                say, "I'm sorry to hear you're feeling anxious. I'm here to help."
                Based on the following user profile and additional requirements:
                Age: {st.session_state.User_profile['Age']}
                Occupation: {st.session_state.User_profile['Occupation']}
                Medical conditions: {st.session_state.User_profile['Medical conditions']}
                
                Additional Requirement: {user_input if user_input else "None Provided"}
                
                Please provide a response that includes:
                1. Provide a safe, and empathetic response, using techniques inspired by cognitive behavioral therapy (CBT) to help the user manage their thoughts and feelings.
                2. Offer a motivational thought or affirmation that is relevant to the user's mood and situation.
                3. Suggest a simple, practical activity or exercise that can help the user feel better, such as a mindfulness technique or a physical stretch.
                Format the output clearly with the following headings and bullet points. **Start the response with a friendly and supportive greeting and end with a gentle
                disclaimer that you are an AI and not a substitute for professional help.**
                """
                response = get_gemini_response(prompt)
                
                st.subheader("Personalized Professional counselors")
                st.markdown(response)

with tab2:
    st.title("Diary")
    st.markdown("Write freely about your thoughts. This is just")
    dia_input = st.text_area("Today's reflection",
                             placeholder="Write anything you want to reflect on ...")
    if st.button("Save Entry", key="dia_save"):
        if dia_input:
            current_date_str = datetime.now().strftime("%Y-%m-%d")
            if st.session_state.dia_entries and st.session_state.dia_entries[-1]['date'] == current_date_str:
                st.session_state.dia_entries[-1]['text'] += f"\n\n---\n\n{dia_input}"
            else:
                entry_with_date = {
                    "date": current_date_str,
                    "text": dia_input
                }
                st.session_state.dia_entries.append(entry_with_date)
            st.success("Diary entry saved!")
    if st.session_state.dia_entries:
        st.markdown("### Your Entries")
        for entry in st.session_state.dia_entries:
            st.markdown(f"**Date:** {entry['date']}")
            st.markdown(entry['text'])
            st.markdown("---")
# Out:
# Overwriting app1.py
